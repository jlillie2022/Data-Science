# %% [markdown]
# <a href="https://colab.research.google.com/github/jlillie2022/Data-Science/blob/main/Jenna_Lillie_lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv') #defines functions and classes which help in opening URLs
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f341fd27400>)

# %%
cereal_data = pd.read_csv('cereal_data.csv') #a comma-separated values

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
cereal_data #defines data set
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"].mean() #finds mean of certain data point
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe() #gives all numbers for data
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
cereal_data[["calories", "sugars"]] #shows the 2 chunks from data set
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.') #plot chart for specific data

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %%
from sklearn.linear_model import LinearRegression #x array will now have two or more columns
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y) #Predict using the linear model
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.') #coordinates of the points or line nodes are given by x, y
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50) #Return evenly spaced numbers over a specified interval

# %%
noise = 10 * np.random.randn(50,) #used to return random values from the normal distribution in a specified shape

# %%
y = 3 * x + 7 + noise

# %%
plt.plot(x,y,'.'); #Plot y versus x as markers

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2) #sum the rows and columns

# %%
loss
# Out:
# 6244.196064633445

# %%
for m_guess in np.linspace(-10,10,10): #create an evenly or non-evenly spaced range of numbers
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 426009.7455050364 -10.0 -10.0
# 407811.5225590381 -10.0 -7.777777777777778
# 390107.1267735335 -10.0 -5.555555555555555
# 372896.55814852274 -10.0 -3.333333333333333
# 356179.81668400584 -10.0 -1.1111111111111107
# 339956.9023799827 -10.0 1.1111111111111107
# 324227.81523645355 -10.0 3.333333333333334
# 308992.5552534181 -10.0 5.555555555555557
# 294251.1224308765 -10.0 7.777777777777779
# 280003.51676882873 -10.0 10.0
# 316691.52062318276 -7.777777777777778 -10.0
# 300962.43347965344 -7.777777777777778 -7.777777777777778
# 285727.173496618 -7.777777777777778 -5.555555555555555
# 270985.7406740764 -7.777777777777778 -3.333333333333333
# 256738.13501202868 -7.777777777777778 -1.1111111111111107
# 242984.35651047475 -7.777777777777778 1.1111111111111107
# 229724.40516941462 -7.777777777777778 3.333333333333334
# 216958.28098884836 -7.777777777777778 5.555555555555557
# 204685.98396877592 -7.777777777777778 7.777777777777779
# 192907.51410919722 -7.777777777777778 10.0
# ...

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20): 
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 97838.68868415142 -3.6842105263157894 3.6842105263157894
# 93921.46334900479 -3.6842105263157894 4.7368421052631575
# 90115.04133795782 -3.6842105263157894 5.789473684210526
# 86419.42265101061 -3.6842105263157894 6.842105263157894
# 82834.60728816311 -3.6842105263157894 7.894736842105264
# 79360.59524941535 -3.6842105263157894 8.94736842105263
# 75997.3865347673 -3.6842105263157894 10.0
# 73572.53045295019 -2.6315789473684212 3.6842105263157894
# 70209.32173830215 -2.6315789473684212 4.7368421052631575
# 66956.91634775382 -2.6315789473684212 5.789473684210526
# 63815.31428130522 -2.6315789473684212 6.842105263157894
# 60784.51553895633 -2.6315789473684212 7.894736842105264
# 57864.52012070718 -2.6315789473684212 8.94736842105263
# 55055.32802655774 -2.6315789473684212 10.0
# 53037.50456388248 -1.578947368421053 3.6842105263157894
# 50228.31246973304 -1.578947368421053 4.7368421052631575
# 47529.92369968334 -1.578947368421053 5.789473684210526
# ...
